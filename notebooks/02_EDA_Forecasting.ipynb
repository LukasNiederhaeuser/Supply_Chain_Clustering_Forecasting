# %%
# Import libraries
import pandas as pd
import sys
import os
import warnings
import matplotlib.pyplot as plt
import statsmodels

from statsmodels.tsa.seasonal import STL
from src.data_preparation_forecasting import load_data, data_cleaning_forecasting, create_features

# Set options for displaying dataframes and figures
pd.set_option('display.max_columns', None)
warnings.filterwarnings("ignore", category=FutureWarning)
pd.options.mode.chained_assignment = None

FILENAME_CLUSTERING = "data_sales_processed.csv"
DATA_FOLDER = "../data/processed"
filename = os.path.join(DATA_FOLDER, FILENAME_CLUSTERING)

# %% [markdown]
# # EDA Forecasting

# %% [markdown]
# In below code of the notebook, the obtained time series will be investigated in an exploratory manner. This includes checking whether the time-series display any systematic components such as trends or seasonality, in order to establish an idea of the modeling possibilities.

# %% [markdown]
# ## Explore the time-series

# %%
# Call the create features function to save the processed dataframe
create_features()
# Out:
# Processed version of data_sales.csv successfully saved in folder

# %%
# Load the data from the processed folder
df_sales = pd.read_csv(filename, delimiter=",")
df_sales.set_index("Date", inplace=True)

# %%
# Define the figure size and subplots
fig, (ax1) = plt.subplots(1, 1, figsize=(12, 4), sharex=True)

# Plotting the time-series for fanshop products
ax1.plot(df_sales['Sales_Qty'], color = 'blue', linewidth = 1.0)
ax1.set_ylabel('Sales Quantity')
ax1.set_title('Sales Quantity Time Series')
ax1.set_ylim(bottom=0)
ax1.grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# **Interpretation:** all three time series do not display trends.

# %% [markdown]
# ### Decompose the time-series

# %%
# Decomposition of the footwear data
stl_decomposition = STL(df_sales['Sales_Qty'], period = 12).fit()
fig = stl_decomposition.plot()

# Defining the plot specification
fig.set_size_inches(10, 8) 
fig.suptitle("STL Decomposition of Time-Series", fontsize=14)
plt.show()

# %% [markdown]
# # Forecasting

# %%
# Create the features
df_sales = create_features(df_sales)

# %%
import pycaret
from pycaret.time_series import *

# %%
plot_model(plot = "train_test_split")

# %%
plot_model(plot = "cv")

# %%
# Plot diagnostics for the model
plot_model(plot="diagnostics")

# %%
best_fanshop = compare_models()
# Out:
# <style type="text/css">
# #T_21fcf th {
#   text-align: left;
# }
# ...

# %%
predict_model(best_fanshop, fh = 60)
# Out:
# <style type="text/css">
# </style>
# <table id="T_ff211">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ff211_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_ff211_level0_col1" class="col_heading level0 col1" >MASE</th>
#       <th id="T_ff211_level0_col2" class="col_heading level0 col2" >RMSSE</th>
#       <th id="T_ff211_level0_col3" class="col_heading level0 col3" >MAE</th>
#       <th id="T_ff211_level0_col4" class="col_heading level0 col4" >RMSE</th>
#       <th id="T_ff211_level0_col5" class="col_heading level0 col5" >MAPE</th>
#       <th id="T_ff211_level0_col6" class="col_heading level0 col6" >SMAPE</th>
#       <th id="T_ff211_level0_col7" class="col_heading level0 col7" >R2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ff211_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ff211_row0_col0" class="data row0 col0" >Grand Means Forecaster</td>
# ...

# %%
finalize_best_fanshop = finalize_model(best_fanshop)

# %%
plot_model(best_fanshop, plot = "forecast")

# %%
# If you specifically want to use auto_arima, you can create the model
auto_arima_model = create_model('auto_arima')
# Out:
# <style type="text/css">
# #T_caf9f_row3_col0, #T_caf9f_row3_col1, #T_caf9f_row3_col2, #T_caf9f_row3_col3, #T_caf9f_row3_col4, #T_caf9f_row3_col5, #T_caf9f_row3_col6, #T_caf9f_row3_col7 {
#   background: yellow;
# }
# </style>
# <table id="T_caf9f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_caf9f_level0_col0" class="col_heading level0 col0" >cutoff</th>
#       <th id="T_caf9f_level0_col1" class="col_heading level0 col1" >MASE</th>
#       <th id="T_caf9f_level0_col2" class="col_heading level0 col2" >RMSSE</th>
#       <th id="T_caf9f_level0_col3" class="col_heading level0 col3" >MAE</th>
#       <th id="T_caf9f_level0_col4" class="col_heading level0 col4" >RMSE</th>
#       <th id="T_caf9f_level0_col5" class="col_heading level0 col5" >MAPE</th>
#       <th id="T_caf9f_level0_col6" class="col_heading level0 col6" >SMAPE</th>
#       <th id="T_caf9f_level0_col7" class="col_heading level0 col7" >R2</th>
#     </tr>
#   </thead>
#   <tbody>
# ...

# %%
final_best_fanshop = finalize_model(auto_arima_model)

# %%
plot_model(final_best_fanshop, plot = "forecast")
